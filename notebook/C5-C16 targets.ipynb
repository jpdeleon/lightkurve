# %% [markdown]
# # C5/C16

# %% [markdown]
# * [gsheet](https://docs.google.com/spreadsheets/d/1mgJqGv7Kdom6RihY5qIUEoYnRUNXVwKXEQNTkQIaa5w/edit#gid=0)

# %%
from glob import glob

glob('../data/*.csv')
# Out:
# ['../data/K2Campaign16targets.csv',
#  '../data/K2Campaign16targets_edited.csv',
#  '../data/C16_epics_mag10-12.csv',
#  '../data/kesprint c5 in c16.csv',
#  '../data/c6_c17_epics.csv',
#  '../data/Yu2018_candidates.csv']

# %%
import pandas as pd

fname='../data/kesprint c5 in c16.csv'
df=pd.read_csv(fname,delimiter=',')
df
# Out:
#          epic          ra        dec  kepmag  \
# 0   211432167  132.863806  12.127919   8.550
# 1   211915147  129.788750  18.951869   9.023
# 2   211945201  136.573975  19.402252  10.115
# 3   212099230  128.073571  22.006011  10.513
# 4   211886472  137.132531  18.528543  11.126
# 5   212110888  127.578770  22.235908  11.441
# 6   211733267  130.009413  16.372406  12.150
# 7   212011230  136.241018  20.440816  12.375
# 8   212006344  126.476311  20.359569  12.466
# 9   211606790  137.144439  14.630882  12.673
# 10  212164470  129.813631  23.357481  12.704
# 11  211408138  132.824965  11.765055  12.740
# 12  211919004  129.777047  19.010023  13.131
# 13  211490999  130.798847  13.009593  13.416
# 14  211529065  131.266597  13.549833  13.431
# 15  211413752  133.709545  11.848265  13.539
# 16  211816003  132.621120  17.542445  13.654
# 17  212069861  134.444189  21.453533  14.102
# 18  212110007  133.310979  22.218977  14.245
# 19  211537406  135.605691  13.665386  14.565
# ...
